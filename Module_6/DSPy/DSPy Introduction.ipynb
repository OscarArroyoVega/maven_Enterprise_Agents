# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzafarooq/multi-agent-course/blob/main/Module_6/DSPy/DSPy%20Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to [DSPy](https://github.com/stanfordnlp/dspy?tab=readme-ov-file)

# %% [markdown]
# ## 1. Installing the requirements

# %%
# !pip install dspy-ai
# Out:
# Collecting dspy-ai
#   Downloading dspy_ai-2.6.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting dspy>=v2.6.3 (from dspy-ai)
#   Downloading dspy-2.6.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (3.7.1)
# Collecting asyncer==0.0.8 (from dspy>=v2.6.3->dspy-ai)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Collecting backoff (from dspy>=v2.6.3->dspy-ai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (5.5.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (3.1.1)
# Collecting datasets (from dspy>=v2.6.3->dspy-ai)
#   Downloading datasets-3.3.1-py3-none-any.whl.metadata (19 kB)
# Collecting diskcache (from dspy>=v2.6.3->dspy-ai)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (0.28.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (3.1.5)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (1.4.2)
# Collecting json-repair (from dspy>=v2.6.3->dspy-ai)
#   Downloading json_repair-0.39.0-py3-none-any.whl.metadata (11 kB)
# Collecting litellm<2.0.0,>=1.59.8 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading litellm-1.61.8-py3-none-any.whl.metadata (37 kB)
# Collecting magicattr~=0.1.6 (from dspy>=v2.6.3->dspy-ai)
#   Downloading magicattr-0.1.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (1.61.1)
# Collecting optuna (from dspy>=v2.6.3->dspy-ai)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (2.2.2)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (2.10.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (2.32.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (9.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dspy>=v2.6.3->dspy-ai) (4.67.1)
# Collecting ujson (from dspy>=v2.6.3->dspy-ai)
#   Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio->dspy>=v2.6.3->dspy-ai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->dspy>=v2.6.3->dspy-ai) (1.3.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (3.11.12)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (8.1.8)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (8.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (4.23.0)
# Collecting python-dotenv>=0.2.0 (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting tiktoken>=0.7.0 (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (0.21.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->dspy>=v2.6.3->dspy-ai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->dspy>=v2.6.3->dspy-ai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->dspy>=v2.6.3->dspy-ai) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->dspy>=v2.6.3->dspy-ai) (3.0.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2.10.1)
# Collecting apscheduler<4.0.0,>=3.10.4 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading APScheduler-3.11.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (43.0.3)
# Collecting fastapi<0.116.0,>=0.115.5 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting fastapi-sso<0.17.0,>=0.16.0 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading fastapi_sso-0.16.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gunicorn<23.0.0,>=22.0.0 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.9.7 in /usr/local/lib/python3.11/dist-packages (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (3.10.15)
# Collecting pynacl<2.0.0,>=1.5.0 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Collecting python-multipart<0.0.19,>=0.0.18 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading python_multipart-0.0.18-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (6.0.2)
# Collecting rq (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading rq-2.1.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting uvicorn<0.30.0,>=0.29.0 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting uvloop<0.22.0,>=0.21.0 (from litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->dspy>=v2.6.3->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->dspy>=v2.6.3->dspy-ai) (0.8.2)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai->dspy>=v2.6.3->dspy-ai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->dspy>=v2.6.3->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->dspy>=v2.6.3->dspy-ai) (2.27.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->dspy>=v2.6.3->dspy-ai) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets->dspy>=v2.6.3->dspy-ai) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->dspy>=v2.6.3->dspy-ai) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->dspy>=v2.6.3->dspy-ai)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->dspy>=v2.6.3->dspy-ai)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->dspy>=v2.6.3->dspy-ai)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->dspy>=v2.6.3->dspy-ai) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->dspy>=v2.6.3->dspy-ai) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->dspy>=v2.6.3->dspy-ai) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dspy>=v2.6.3->dspy-ai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dspy>=v2.6.3->dspy-ai) (2.3.0)
# Collecting alembic>=1.5.0 (from optuna->dspy>=v2.6.3->dspy-ai)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->dspy>=v2.6.3->dspy-ai)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->dspy>=v2.6.3->dspy-ai) (2.0.38)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->dspy>=v2.6.3->dspy-ai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->dspy>=v2.6.3->dspy-ai) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->dspy>=v2.6.3->dspy-ai) (2025.1)
# Collecting Mako (from alembic>=1.5.0->optuna->dspy>=v2.6.3->dspy-ai)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.11/dist-packages (from apscheduler<4.0.0,>=3.10.4->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (5.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44.0.0,>=43.0.1->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (1.17.1)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi<0.116.0,>=0.115.5->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from fastapi-sso<0.17.0,>=0.16.0->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (3.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.59.8->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (0.22.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->dspy>=v2.6.3->dspy-ai) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->dspy>=v2.6.3->dspy-ai) (3.1.1)
# Collecting redis>=3.5 (from rq->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2.22)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pydantic[email]>=1.8.0->fastapi-sso<0.17.0,>=0.16.0->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from email-validator>=2.0.0->pydantic[email]>=1.8.0->fastapi-sso<0.17.0,>=0.16.0->litellm[proxy]<2.0.0,>=1.59.8->dspy>=v2.6.3->dspy-ai) (2.7.0)
# Downloading dspy_ai-2.6.3-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.3/255.3 kB 15.2 MB/s eta 0:00:00
# Downloading dspy-2.6.3-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.0/256.0 kB 25.3 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading litellm-1.61.8-py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.0 MB/s eta 0:00:00
# Downloading magicattr-0.1.6-py2.py3-none-any.whl (4.7 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading datasets-3.3.1-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 33.0 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.1 MB/s eta 0:00:00
# Downloading json_repair-0.39.0-py3-none-any.whl (20 kB)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 35.9 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.6 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 24.2 MB/s eta 0:00:00
# Downloading APScheduler-3.11.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 6.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.4 MB/s eta 0:00:00
# Downloading fastapi_sso-0.16.0-py3-none-any.whl (23 kB)
# Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 9.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.7 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 43.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_multipart-0.0.18-py3-none-any.whl (24 kB)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.8 MB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.3 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 52.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading rq-2.1.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 10.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.9 MB/s eta 0:00:00
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 21.2 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.9 MB/s eta 0:00:00
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: magicattr, xxhash, uvloop, uvicorn, ujson, redis, python-multipart, python-dotenv, Mako, json-repair, gunicorn, diskcache, dill, colorlog, backoff, apscheduler, tiktoken, starlette, rq, pynacl, multiprocess, asyncer, alembic, optuna, fastapi, litellm, fastapi-sso, datasets, dspy, dspy-ai
# Successfully installed Mako-1.3.9 alembic-1.14.1 apscheduler-3.11.0 asyncer-0.0.8 backoff-2.2.1 colorlog-6.9.0 datasets-3.3.1 dill-0.3.8 diskcache-5.6.3 dspy-2.6.3 dspy-ai-2.6.3 fastapi-0.115.8 fastapi-sso-0.16.0 gunicorn-22.0.0 json-repair-0.39.0 litellm-1.61.8 magicattr-0.1.6 multiprocess-0.70.16 optuna-4.2.1 pynacl-1.5.0 python-dotenv-1.0.1 python-multipart-0.0.18 redis-5.2.1 rq-2.1.0 starlette-0.45.3 tiktoken-0.9.0 ujson-5.10.0 uvicorn-0.29.0 uvloop-0.21.0 xxhash-3.5.0

# %%
import dspy
import sys
import os

# %% [markdown]
# ## 2. Setting up your LM and RM
#
# We'll start by setting up the language model (LM) and retrieval model (RM).
#
# In this notebook, we'll work with GPT-4o and the retriever ColBERTv2.
#
# To make things easy, we've set up a ColBERTv2 server hosting a Wikipedia 2017 "abstracts" search index (i.e., containing first paragraph of each article from this 2017 dump).

# %%
turbo = dspy.LM(model = 'gpt-4o-mini')
colbertv2_wiki17_abstracts = dspy.ColBERTv2(url = 'http://20.102.90.50:2017/wiki17_abstracts')
dspy.settings.configure(lm = turbo, rm = colbertv2_wiki17_abstracts)

# %%
from dspy.datasets import HotPotQA #HotPotQA dataset is used to benchmark multi-hop QA

# Load the dataset.
dataset = HotPotQA(train_seed=1, train_size=20, eval_seed=2023, dev_size=50, test_size=0) #Notice the size of training and dev dataset! Teeny tiny compared to other ML models.

# Tell DSPy that the 'question' field is the input. Any other fields are labels and/or metadata.
trainset = [x.with_inputs('question') for x in dataset.train]
devset = [x.with_inputs('question') for x in dataset.dev]

len(trainset), len(devset)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/9.19k [00:00<?, ?B/s]
# hotpot_qa.py:   0%|          | 0.00/6.42k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/566M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/47.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/46.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/90447 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/7405 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7405 [00:00<?, ? examples/s]
# (20, 50)

# %% [markdown]
# Let's check some examples!

# %%
for i in range(5):
  train_example = trainset[i]
  print(f"Question: {train_example.question}")
  print(f"Answer: {train_example.answer}", '\n')
# Out:
# Question: At My Window was released by which American singer-songwriter?
# Answer: John Townes Van Zandt
#
# Question: which  American actor was Candace Kita  guest starred with
# Answer: Bill Murray
#
# Question: Which of these publications was most recently published, Who Put the Bomp or Self?
# Answer: Self
#
# Question: The Victorians - Their Story In Pictures is a documentary series written by an author born in what year?
# Answer: 1950
#
# Question: Which magazine has published articles by Scott Shaw, Tae Kwon Do Times or Southwest Art?
# Answer: Tae Kwon Do Times

# %% [markdown]
# As you see, not all questions are multi-hop, e.g. the very first one. But, the second question is one such question as it requires breaking up the question into pieces in order to provide an answer.
#
# Let's check an example from the development dataset. While we will not touch this for training, we will use this for metric evaluation.

# %%
dev_example = devset[18]
print(f"Question: {dev_example.question}")
print(f"Answer: {dev_example.answer}")
print(f"Relevant Wikipedia Titles: {dev_example.gold_titles}")
# Out:
# Question: What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
# Answer: English
# Relevant Wikipedia Titles: {'Robert Irvine', 'Restaurant: Impossible'}

# %%
#This cell instructs how the data is presented to the model
print(f"For this dataset, training examples have input keys {train_example.inputs().keys()} and label keys {train_example.labels().keys()}")
print(f"For this dataset, dev examples have input keys {dev_example.inputs().keys()} and label keys {dev_example.labels().keys()}")
# Out:
# For this dataset, training examples have input keys ['question'] and label keys ['answer']
# For this dataset, dev examples have input keys ['question'] and label keys ['answer', 'gold_titles']

# %% [markdown]
# ## 3. Defining simple Signature and Predictor

# %%
class BasicQA(dspy.Signature):
    """Answer questions with short factoid answers."""

    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")

# %%
import os

os.environ["OPENAI_API_KEY"] = 'your api key'  #my key redacted - add your own key here

# Define the predictor.
generate_answer = dspy.Predict(BasicQA)

# Call the predictor on a particular input.
pred = generate_answer(question=dev_example.question)

# Print the input and the prediction.
print(f"Question: {dev_example.question}")
print(f"Predicted Answer: {pred.answer}")
# Out:
# Question: What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
# Predicted Answer: American

# %% [markdown]
# ^ If this gives an error complaining about not having and API_Key, click on the link and get a key. And run the following command:

# %% [markdown]
# **Wrong answer**. The chef is [Robert Irvine](https://en.wikipedia.org/wiki/Robert_Irvine), who is in fact British.
#
#
# We can explore the history of this answer.

# %%
turbo.inspect_history(n=1)
# Out:
# [2025-02-18T20:13:42.557285]
#
# System message:
#
# Your input fields are:
# 1. `question` (str)
#
# Your output fields are:
# 1. `answer` (str): often between 1 and 5 words
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# [[ ## question ## ]]
# What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
#
# Respond with the corresponding output fields, starting with the field `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## answer ## ]]
# American
#
# [[ ## completed ## ]]

# %% [markdown]
# There is no reasoning or chain of thought in the history of the LLM provided above. Instead of using `Predict`, we will use the `ChainOfThought` module of the `DSPy`.

# %%
dev_example = devset[18]
print(f"Question: {dev_example.question}")
print(f"Answer: {dev_example.answer}")
print(f"Relevant Wikipedia Titles: {dev_example.gold_titles}")
# Out:
# Question: What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
# Answer: English
# Relevant Wikipedia Titles: {'Robert Irvine', 'Restaurant: Impossible'}

# %%
# Replacing the dspy.Predict(BasicQA) with dspy.ChainOfThought(BasicQA) -> Notice that the BasicQA signature in untouched.
generate_answer_with_chain_of_thought = dspy.ChainOfThought(BasicQA)

# Call the predictor on the same input.
pred = generate_answer_with_chain_of_thought(question=dev_example.question)

# Print the input, the chain of thought, and the prediction.
print(f"Question: {dev_example.question}")
print(f"Predicted Answer: {pred.answer}")
# Out:
# Question: What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
# Predicted Answer: British

# %%
turbo.inspect_history(n=1)
# Out:
# [2025-02-18T20:14:46.782444]
#
# System message:
#
# Your input fields are:
# 1. `question` (str)
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (str): often between 1 and 5 words
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# [[ ## question ## ]]
# What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The chef and restaurateur featured in "Restaurant: Impossible" is Robert Irvine, who is British. He is known for his work in the culinary industry and has gained fame through his television appearances.
#
# [[ ## answer ## ]]
# British
#
# [[ ## completed ## ]]

# %% [markdown]
# ## 4. Retrieval and basic RAG

# %%
retrieve = dspy.Retrieve(k=3)
topK_passages = None
while True:
    try:
        topK_passages = retrieve(dev_example.question).passages
        break
    except Exception as e:
        continue

print(f"Top {retrieve.k} passages for question: {dev_example.question} \n", '-' * 30, '\n')

for idx, passage in enumerate(topK_passages):
    print(f'{idx+1}]', passage, '\n')
# Out:
# Top 3 passages for question: What is the nationality of the chef and restaurateur featured in Restaurant: Impossible?
#  ------------------------------
#
# 1] Restaurant: Impossible | Restaurant: Impossible is an American reality television series, featuring chef and restaurateur Robert Irvine, that aired on Food Network from 2011 to 2016.
#
# 2] Jean Joho | Jean Joho is a French-American chef and restaurateur. He is chef/proprietor of Everest in Chicago (founded in 1986), Paris Club Bistro & Bar and Studio Paris in Chicago, The Eiffel Tower Restaurant in Las Vegas, and Brasserie JO in Boston.
#
# 3] List of Restaurant: Impossible episodes | This is the list of the episodes for the American cooking and reality television series "Restaurant Impossible", produced by Food Network. The premise of the series is that within two days and on a budget of $10,000, celebrity chef Robert Irvine renovates a failing American restaurant with the goal of helping to restore it to profitability and prominence. Irvine is assisted by a designer (usually Taniya Nayak, Cheryl Torrenueva, or Lynn Keagan, but sometimes Vanessa De Leon, Krista Watterworth, Yvette Irene, or Nicole Faccuito), along with general contractor Tom Bury, who sometimes does double duty as both general contractor and designer. After assessing the problems with the restaurant, Robert Irvine typically creates a plan for the new decor, oversees the cleaning of the restaurant, reduces the size of the menu and improves the food, develops a promotional activity, educates the restaurant's owners, or trains the staff, as needed by each restaurant.

# %%
topK_passages
# Out:
# ['Restaurant: Impossible | Restaurant: Impossible is an American reality television series, featuring chef and restaurateur Robert Irvine, that aired on Food Network from 2011 to 2016.',
#  'Jean Joho | Jean Joho is a French-American chef and restaurateur. He is chef/proprietor of Everest in Chicago (founded in 1986), Paris Club Bistro & Bar and Studio Paris in Chicago, The Eiffel Tower Restaurant in Las Vegas, and Brasserie JO in Boston.',
#  'List of Restaurant: Impossible episodes | This is the list of the episodes for the American cooking and reality television series "Restaurant Impossible", produced by Food Network. The premise of the series is that within two days and on a budget of $10,000, celebrity chef Robert Irvine renovates a failing American restaurant with the goal of helping to restore it to profitability and prominence. Irvine is assisted by a designer (usually Taniya Nayak, Cheryl Torrenueva, or Lynn Keagan, but sometimes Vanessa De Leon, Krista Watterworth, Yvette Irene, or Nicole Faccuito), along with general contractor Tom Bury, who sometimes does double duty as both general contractor and designer. After assessing the problems with the restaurant, Robert Irvine typically creates a plan for the new decor, oversees the cleaning of the restaurant, reduces the size of the menu and improves the food, develops a promotional activity, educates the restaurant\'s owners, or trains the staff, as needed by each restaurant.']

# %%
#check 3 passages for the same question
for i in range(3):
  while True:
    try:
      print(retrieve(dev_example.question).passages[i], '\n')
      break
    except Exception as e:
      continue
# Out:
# Restaurant: Impossible | Restaurant: Impossible is an American reality television series, featuring chef and restaurateur Robert Irvine, that aired on Food Network from 2011 to 2016.
#
# Jean Joho | Jean Joho is a French-American chef and restaurateur. He is chef/proprietor of Everest in Chicago (founded in 1986), Paris Club Bistro & Bar and Studio Paris in Chicago, The Eiffel Tower Restaurant in Las Vegas, and Brasserie JO in Boston.
#
# List of Restaurant: Impossible episodes | This is the list of the episodes for the American cooking and reality television series "Restaurant Impossible", produced by Food Network. The premise of the series is that within two days and on a budget of $10,000, celebrity chef Robert Irvine renovates a failing American restaurant with the goal of helping to restore it to profitability and prominence. Irvine is assisted by a designer (usually Taniya Nayak, Cheryl Torrenueva, or Lynn Keagan, but sometimes Vanessa De Leon, Krista Watterworth, Yvette Irene, or Nicole Faccuito), along with general contractor Tom Bury, who sometimes does double duty as both general contractor and designer. After assessing the problems with the restaurant, Robert Irvine typically creates a plan for the new decor, oversees the cleaning of the restaurant, reduces the size of the menu and improves the food, develops a promotional activity, educates the restaurant's owners, or trains the staff, as needed by each restaurant.

# %%
class GenerateAnswer(dspy.Signature):
    """Answer questions with short factoid answers."""

    context = dspy.InputField(desc="may contain relevant facts")
    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")

# %%
class RAG(dspy.Module):
    def __init__(self, num_passages=3):
        super().__init__()

        self.retrieve = dspy.Retrieve(k=num_passages)
        self.generate_answer = dspy.ChainOfThought(GenerateAnswer)

    def forward(self, question):
        context = self.retrieve(question).passages
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

# %% [markdown]
# Time for optimizer.

# %%
from dspy.teleprompt import BootstrapFewShot

# Validation logic: check that the predicted answer is correct.
# Also check that the retrieved context does actually contain that answer.
def validate_context_and_answer(example, pred, trace=None):
    answer_EM = dspy.evaluate.answer_exact_match(example, pred) #This metric is Exact Match
    return answer_EM

# Set up a basic teleprompter, which will compile our RAG program.
teleprompter = BootstrapFewShot(metric=validate_context_and_answer) #This line bootstraps few-shot examples

# Compile!
compiled_rag = None
while True:
    try:
      compiled_rag = teleprompter.compile(RAG(), trainset=trainset)
      break
    except Exception as e:
      print(f"Exception: {str(e)}")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#  30%|███       | 6/20 [00:02<00:05,  2.66it/s]
# Bootstrapped 4 full traces after 6 examples for up to 1 rounds, amounting to 6 attempts.

# %% [markdown]
# ^ It'll stop once it has reached some performance threshold.

# %%
# Ask any question you like to this simple RAG program.
my_question = "What castle did David Gregory inherit?"

# Get the prediction. This contains `pred.context` and `pred.answer`.
pred = None
while True:
    try:
      pred = compiled_rag(my_question)
      break
    except Exception as e:
      continue

# Print the contexts and the answer.
print(f"Question: {my_question}")
print(f"Predicted Answer: {pred.answer}")
# Out:
# Question: What castle did David Gregory inherit?
# Predicted Answer: Kinnairdy Castle

# %%
# Let's check the retrieved passage

print(f"Retrieved Contexts (truncated): {[c[:200] + '...' for c in pred.context]}")
# Out:
# Retrieved Contexts (truncated): ['David Gregory (physician) | David Gregory (20 December 1625 – 1720) was a Scottish physician and inventor. His surname is sometimes spelt as Gregorie, the original Scottish spelling. He inherited Kinn...', 'Gregory Tarchaneiotes | Gregory Tarchaneiotes (Greek: Γρηγόριος Ταρχανειώτης , Italian: "Gregorio Tracanioto" or "Tracamoto" ) was a "protospatharius" and the long-reigning catepan of Italy from 998 t...', 'David Gregory (mathematician) | David Gregory (originally spelt Gregorie) FRS (? 1659 – 10 October 1708) was a Scottish mathematician and astronomer. He was professor of mathematics at the University ...']

# %% [markdown]
# **For Readability:**
#
# Retrieved Contexts (truncated): ['David Gregory (physician) | David Gregory (20 December 1625 – 1720) was a Scottish physician and inventor. His surname is sometimes spelt as Gregorie, the original Scottish spelling. He inherited Kinn...', 'Gregory Tarchaneiotes | Gregory Tarchaneiotes (Greek: Γρηγόριος Ταρχανειώτης , Italian: "Gregorio Tracanioto" or "Tracamoto" ) was a "protospatharius" and the long-reigning catepan of Italy from 998 t...', 'David Gregory (mathematician) | David Gregory (originally spelt Gregorie) FRS (? 1659 – 10 October 1708) was a Scottish mathematician and astronomer. He was professor of mathematics at the University ...']
#
# **And the wikipedia link**: [David Gregory](https://en.wikipedia.org/wiki/David_Gregory_(physician)

# %%
turbo.inspect_history(n=1) #To see the last context the LLM has seen. If you wanna see the previous context, you can set "n" to that number
# Out:
# [2025-02-18T20:17:20.708274]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts
# 2. `question` (str)
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (str): often between 1 and 5 words
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# At My Window was released by which American singer-songwriter?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# John Townes Van Zandt
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# "Everything Has Changed" is a song from an album released under which record label ?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Big Machine Records
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Which American actress who made their film debut in the 1995 teen drama "Kids" was the co-founder of Voto Latino?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Rosario Dawson
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Which Pakistani cricket umpire who won 3 consecutive ICC umpire of the year awards in 2009, 2010, and 2011 will be in the ICC World Twenty20?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Aleem Sarwar Dar
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Having the combination of excellent foot speed and bat speed helped Eric Davis, create what kind of outfield for the Los Angeles Dodgers?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# "Outfield of Dreams"
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Who is older, Aleksandr Danilovich Aleksandrov or Anatoly Fomenko?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Aleksandr Danilovich Aleksandrov
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# The Organisation that allows a community to influence their operation or use and to enjoy the benefits arisingwas founded in what year?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# 2010
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Who acted in the shot film The Shore and is also the youngest actress ever to play Ophelia in a Royal Shakespeare Company production of "Hamlet." ?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Kerry Condon
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Tombstone stared an actor born May 17, 1955 known as who?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Bill Paxton
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# which  American actor was Candace Kita  guest starred with
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Bill Murray
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# What is the code name for the German offensive that started this Second World War engagement on the Eastern Front (a few hundred kilometers from Moscow) between Soviet and German forces, which included 102nd Infantry Division?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Operation Citadel
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## context ## ]]
# Not supplied for this particular example.
#
# [[ ## question ## ]]
# Which company distributed this 1977 American animated film produced by Walt Disney Productions for which Sherman Brothers wrote songs?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Buena Vista Distribution
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «Who Put the Bomp | Who Put The Bomp was a rock music fanzine edited and published by Greg Shaw from 1970 to 1979. Its name came from the hit 1961 doo-wop song by Barry Mann, "Who Put the Bomp". Later, the name was shortened to "Bomp!"»
# [2] «Bompiani | Bompiani is an Italian publishing house based in Milan, Italy. It was founded in 1929 by Valentino Bompiani.»
# [3] «What Color is Your Parachute? | What Color is Your Parachute? by Richard Nelson Bolles is a book for job-seekers that has been in print since 1970 and has been revised every year since 1975, sometimes substantially. Bolles initially self-published the book (December 1, 1970), but it has been commercially published since November 1972 by Ten Speed Press in Berkeley, California. As of September 28, 2010, the book is available in 22 languages, it is used in 26 countries around the world, and over ten million copies have been sold worldwide. It is one of the most highly regarded career advice books in print. In the latest edition of the book, the author writes about how to adapt one's job search to the Web 2.0 age.»
#
# [[ ## question ## ]]
# Which of these publications was most recently published, Who Put the Bomp or Self?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# "Who Put the Bomp" was published from 1970 to 1979, while "Self" is a magazine that has been published since 1979 and continues to be released. Therefore, "Self" is the more recent publication.
#
# [[ ## answer ## ]]
# Self
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «The Victorians | The Victorians - Their Story In Pictures is a 2009 British documentary series which focuses on Victorian art and culture. The four-part series is written and presented by Jeremy Paxman and debuted on BBC One at 9:00pm on Sunday 15 February 2009.»
# [2] «Victorian (comics) | The Victorian is a 25-issue comic book series published by Penny-Farthing Press and starting in 1999. The brainchild of creator Trainor Houghton, the series included a number of notable script writers and illustrators, including Len Wein, Glen Orbik and Howard Chaykin.»
# [3] «The Great Victorian Collection | The Great Victorian Collection, published in 1975, is a novel by Northern Irish-Canadian writer Brian Moore. Set in Carmel, California, it tells the story of a man who dreams that the empty parking lot he can see from his hotel window has been transformed by the arrival of a collection of priceless Victoriana on display in a vast open-air market. When he awakes he finds that he can no longer distinguish the dream from reality.»
#
# [[ ## question ## ]]
# The Victorians - Their Story In Pictures is a documentary series written by an author born in what year?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The documentary series "The Victorians - Their Story In Pictures" is written and presented by Jeremy Paxman, who was born in 1950.
#
# [[ ## answer ## ]]
# 1950
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «Tae Kwon Do Times | Tae Kwon Do Times is a magazine devoted to the martial art of taekwondo, and is published in the United States of America. While the title suggests that it focuses on taekwondo exclusively, the magazine also covers other Korean martial arts. "Tae Kwon Do Times" has published articles by a wide range of authors, including He-Young Kimm, Thomas Kurz, Scott Shaw, and Mark Van Schuyver.»
# [2] «Kwon Tae-man | Kwon Tae-man (born 1941) was an early Korean hapkido practitioner and a pioneer of the art, first in Korea and then in the United States. He formed one of the earliest dojang's for hapkido in the United States in Torrance, California, and has been featured in many magazine articles promoting the art.»
# [3] «Hee Il Cho | Cho Hee Il (born October 13, 1940) is a prominent Korean-American master of taekwondo, holding the rank of 9th "dan" in the martial art. He has written 11 martial art books, produced 70 martial art training videos, and has appeared on more than 70 martial arts magazine covers. Cho won several national and international competitions as a taekwondo competitor, and has appeared in several films, including "Fight to Win", "Best of the Best", "Bloodsport II", and "Bloodsport III". He founded the Action International Martial Arts Association (AIMAA) in 1980, and is its President. Cho is a member of both "Black Belt" magazine's Hall of Fame and "Tae Kwon Do Times" magazine's Hall of Fame.»
#
# [[ ## question ## ]]
# Which magazine has published articles by Scott Shaw, Tae Kwon Do Times or Southwest Art?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The context states that "Tae Kwon Do Times" has published articles by a wide range of authors, including Scott Shaw. There is no mention of "Southwest Art" in relation to Scott Shaw. Therefore, the magazine that published articles by Scott Shaw is "Tae Kwon Do Times."
#
# [[ ## answer ## ]]
# Tae Kwon Do Times
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «1972 FA Charity Shield | The 1972 FA Charity Shield was contested between Manchester City and Aston Villa.»
# [2] «1968 FA Charity Shield | The 1968 FA Charity Shield was a football match played on 3 August 1968 between Football League champions Manchester City and FA Cup winners West Bromwich Albion. It was the 46th Charity Shield match and was played at City's home ground, Maine Road. Manchester City won 6–1.»
# [3] «1973 FA Charity Shield | The 1973 FA Charity Shield was contested between Burnley and Manchester City in a fixture that took place at Maine Road.»
#
# [[ ## question ## ]]
# In what year was the club founded that played Manchester City in the 1972 FA Charity Shield
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The 1972 FA Charity Shield was contested between Manchester City and Aston Villa. Aston Villa was founded in 1874.
#
# [[ ## answer ## ]]
# 1874
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «David Gregory (physician) | David Gregory (20 December 1625 – 1720) was a Scottish physician and inventor. His surname is sometimes spelt as Gregorie, the original Scottish spelling. He inherited Kinnairdy Castle in 1664. Three of his twenty-nine children became mathematics professors. He is credited with inventing a military cannon that Isaac Newton described as "being destructive to the human species". Copies and details of the model no longer exist. Gregory's use of a barometer to predict farming-related weather conditions led him to be accused of witchcraft by Presbyterian ministers from Aberdeen, although he was never convicted.»
# [2] «Gregory Tarchaneiotes | Gregory Tarchaneiotes (Greek: Γρηγόριος Ταρχανειώτης , Italian: "Gregorio Tracanioto" or "Tracamoto" ) was a "protospatharius" and the long-reigning catepan of Italy from 998 to 1006. In December 999, and again on February 2, 1002, he reinstituted and confirmed the possessions of the abbey and monks of Monte Cassino in Ascoli. In 1004, he fortified and expanded the castle of Dragonara on the Fortore. He gave it three circular towers and one square one. He also strengthened Lucera.»
# [3] «David Gregory (mathematician) | David Gregory (originally spelt Gregorie) FRS (? 1659 – 10 October 1708) was a Scottish mathematician and astronomer. He was professor of mathematics at the University of Edinburgh, Savilian Professor of Astronomy at the University of Oxford, and a commentator on Isaac Newton's "Principia".»
#
# [[ ## question ## ]]
# What castle did David Gregory inherit?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# David Gregory, the Scottish physician, inherited Kinnairdy Castle in 1664, as mentioned in the context.
#
# [[ ## answer ## ]]
# Kinnairdy Castle
#
# [[ ## completed ## ]]

# %% [markdown]
# Inspect the parameters

# %%
for name, parameter in compiled_rag.named_predictors():
  print(name)
  print(parameter.demos[0], '\n')
# Out:
# generate_answer.predict
# Example({'augmented': True, 'context': ['Who Put the Bomp | Who Put The Bomp was a rock music fanzine edited and published by Greg Shaw from 1970 to 1979. Its name came from the hit 1961 doo-wop song by Barry Mann, "Who Put the Bomp". Later, the name was shortened to "Bomp!"', 'Bompiani | Bompiani is an Italian publishing house based in Milan, Italy. It was founded in 1929 by Valentino Bompiani.', "What Color is Your Parachute? | What Color is Your Parachute? by Richard Nelson Bolles is a book for job-seekers that has been in print since 1970 and has been revised every year since 1975, sometimes substantially. Bolles initially self-published the book (December 1, 1970), but it has been commercially published since November 1972 by Ten Speed Press in Berkeley, California. As of September 28, 2010, the book is available in 22 languages, it is used in 26 countries around the world, and over ten million copies have been sold worldwide. It is one of the most highly regarded career advice books in print. In the latest edition of the book, the author writes about how to adapt one's job search to the Web 2.0 age."], 'question': 'Which of these publications was most recently published, Who Put the Bomp or Self?', 'reasoning': '"Who Put the Bomp" was published from 1970 to 1979, while "Self" is a magazine that has been published since 1979 and continues to be released. Therefore, "Self" is the more recent publication.', 'answer': 'Self'}) (input_keys=None)

# %% [markdown]
# ## 5. Evaluate the Model

# %%
from dspy.evaluate import Evaluate

# Set up the `evaluate_on_hotpotqa` function.
evaluate_on_hotpotqa = Evaluate(devset=devset, num_threads=1, display_progress=True, display_table=5)

# Evaluate the `compiled_rag` program with the `answer_exact_match` metric.
metric = None
while True:
    try:
        metric = dspy.evaluate.answer_exact_match
        evaluate_on_hotpotqa(compiled_rag, metric=metric)
        break
    except Exception as e:
        continue

evaluate_on_hotpotqa(compiled_rag, metric=metric)
# Out:
# Average Metric: 29.00 / 50 (58.0%): 100%|██████████| 50/50 [03:20<00:00,  4.00s/it]
# 2025/02/18 20:20:48 INFO dspy.evaluate.evaluate: Average Metric: 29 / 50 (58.0%)
#                                                                 question  \
# 0         Are both Cangzhou and Qionghai in the Hebei province of China?
# 1  Who conducts the draft in which Marc-Andre Fleury was drafted to t...
# 2  The Wings entered a new era, following the retirement of which Can...
# 3                     What river is near the Crichton Collegiate Church?
# 4  In the 10th Century A.D. Ealhswith had a son called Æthelweard by ...
#
#            example_answer  \
# 0                      no
# 1  National Hockey League
# 2           Steve Yzerman
# 3          the River Tyne
# 4   King Alfred the Great
#
#                                                       gold_titles  \
# 0                                            {Cangzhou, Qionghai}
# 1  {2017–18 Pittsburgh Penguins season, 2017 NHL Expansion Draft}
# 2               {Steve Yzerman, 2006–07 Detroit Red Wings season}
# 3                   {Crichton Collegiate Church, Crichton Castle}
# 4                         {Ealhswith, Æthelweard (son of Alfred)}
#
#                                                                  context  \
# 0  ['Cangzhou | Cangzhou () is a prefecture-level city in eastern Heb...
# 1  ['2017–18 Pittsburgh Penguins season | The 2017–18 Pittsburgh Peng...
# 2  ['Steve Yzerman | Stephen Gregory "Steve" Yzerman ( ; born May 9, ...
# 3  ["Crichton Collegiate Church | Crichton Collegiate Church is situa...
# 4  ["Æthelweard of East Anglia | Æthelweard (died 854) was a 9th-cent...
#
#               pred_answer answer_exact_match
# 0                      No          ✔️ [True]
# 1  National Hockey League          ✔️ [True]
# 2           Steve Yzerman          ✔️ [True]
# 3              River Tyne          ✔️ [True]
# 4   King Alfred the Great          ✔️ [True]
#                 <div style='
#                     text-align: center;
#                     font-size: 16px;
#                     font-weight: bold;
#                     color: #555;
#                     margin: 10px 0;'>
#                     ... 45 more rows not displayed ...
#                 </div>
# Average Metric: 29.00 / 50 (58.0%): 100%|██████████| 50/50 [00:00<00:00, 116.24it/s]
# 2025/02/18 20:20:49 INFO dspy.evaluate.evaluate: Average Metric: 29 / 50 (58.0%)
#                                                                 question  \
# 0         Are both Cangzhou and Qionghai in the Hebei province of China?
# 1  Who conducts the draft in which Marc-Andre Fleury was drafted to t...
# 2  The Wings entered a new era, following the retirement of which Can...
# 3                     What river is near the Crichton Collegiate Church?
# 4  In the 10th Century A.D. Ealhswith had a son called Æthelweard by ...
#
#            example_answer  \
# 0                      no
# 1  National Hockey League
# 2           Steve Yzerman
# 3          the River Tyne
# 4   King Alfred the Great
#
#                                                       gold_titles  \
# 0                                            {Cangzhou, Qionghai}
# 1  {2017–18 Pittsburgh Penguins season, 2017 NHL Expansion Draft}
# 2               {Steve Yzerman, 2006–07 Detroit Red Wings season}
# 3                   {Crichton Collegiate Church, Crichton Castle}
# 4                         {Ealhswith, Æthelweard (son of Alfred)}
#
#                                                                  context  \
# 0  ['Cangzhou | Cangzhou () is a prefecture-level city in eastern Heb...
# 1  ['2017–18 Pittsburgh Penguins season | The 2017–18 Pittsburgh Peng...
# 2  ['Steve Yzerman | Stephen Gregory "Steve" Yzerman ( ; born May 9, ...
# 3  ["Crichton Collegiate Church | Crichton Collegiate Church is situa...
# 4  ["Æthelweard of East Anglia | Æthelweard (died 854) was a 9th-cent...
#
#               pred_answer answer_exact_match
# 0                      No          ✔️ [True]
# 1  National Hockey League          ✔️ [True]
# 2           Steve Yzerman          ✔️ [True]
# 3              River Tyne          ✔️ [True]
# 4   King Alfred the Great          ✔️ [True]
#                 <div style='
#                     text-align: center;
#                     font-size: 16px;
#                     font-weight: bold;
#                     color: #555;
#                     margin: 10px 0;'>
#                     ... 45 more rows not displayed ...
#                 </div>
# 58.0

# %%
def gold_passages_retrieved(example, pred, trace=None):
    gold_titles = set(map(dspy.evaluate.normalize_text, example['gold_titles']))
    found_titles = set(map(dspy.evaluate.normalize_text, [c.split(' | ')[0] for c in pred.context]))

    return gold_titles.issubset(found_titles)
compiled_rag_retrieval_score = None

while True:
    try:
        compiled_rag_retrieval_score = evaluate_on_hotpotqa(compiled_rag, metric=gold_passages_retrieved)
        break
    except Exception as e:
        continue
# Out:
# Average Metric: 13.00 / 50 (26.0%): 100%|██████████| 50/50 [00:00<00:00, 109.42it/s]
# 2025/02/18 20:20:49 INFO dspy.evaluate.evaluate: Average Metric: 13 / 50 (26.0%)
#                                                                 question  \
# 0         Are both Cangzhou and Qionghai in the Hebei province of China?
# 1  Who conducts the draft in which Marc-Andre Fleury was drafted to t...
# 2  The Wings entered a new era, following the retirement of which Can...
# 3                     What river is near the Crichton Collegiate Church?
# 4  In the 10th Century A.D. Ealhswith had a son called Æthelweard by ...
#
#            example_answer  \
# 0                      no
# 1  National Hockey League
# 2           Steve Yzerman
# 3          the River Tyne
# 4   King Alfred the Great
#
#                                                       gold_titles  \
# 0                                            {Cangzhou, Qionghai}
# 1  {2017–18 Pittsburgh Penguins season, 2017 NHL Expansion Draft}
# 2               {Steve Yzerman, 2006–07 Detroit Red Wings season}
# 3                   {Crichton Collegiate Church, Crichton Castle}
# 4                         {Ealhswith, Æthelweard (son of Alfred)}
#
#                                                                  context  \
# 0  ['Cangzhou | Cangzhou () is a prefecture-level city in eastern Heb...
# 1  ['2017–18 Pittsburgh Penguins season | The 2017–18 Pittsburgh Peng...
# 2  ['Steve Yzerman | Stephen Gregory "Steve" Yzerman ( ; born May 9, ...
# 3  ["Crichton Collegiate Church | Crichton Collegiate Church is situa...
# 4  ["Æthelweard of East Anglia | Æthelweard (died 854) was a 9th-cent...
#
#               pred_answer gold_passages_retrieved
# 0                      No
# 1  National Hockey League               ✔️ [True]
# 2           Steve Yzerman               ✔️ [True]
# 3              River Tyne               ✔️ [True]
# 4   King Alfred the Great
#                 <div style='
#                     text-align: center;
#                     font-size: 16px;
#                     font-weight: bold;
#                     color: #555;
#                     margin: 10px 0;'>
#                     ... 45 more rows not displayed ...
#                 </div>

# %% [markdown]
# For more advanced topics, refer to https://github.com/stanfordnlp/dspy/tree/main

# %% [markdown]
# <h3 align="center"></h3>
#
#
# <h3 align="center">---Son---</h3>
